# %%
import pandas as pd
from datetime import datetime

# %%
#load dataframe
df = pd.read_csv('./owid-covid-data.csv')
df
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# 2          ABW  North America          Aruba  2020-03-20          4.0
# 3          ABW  North America          Aruba  2020-03-21          NaN
# 4          ABW  North America          Aruba  2020-03-22          NaN
# ...        ...            ...            ...         ...          ...
# 38422      NaN            NaN  International  2020-08-16        696.0
# 38423      NaN            NaN  International  2020-08-17        696.0
# 38424      NaN            NaN  International  2020-08-18        696.0
# 38425      NaN            NaN  International  2020-08-19        696.0
# 38426      NaN            NaN  International  2020-08-20        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df.shape
# Out:
# (38427, 40)

# %%
#display data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38427 entries, 0 to 38426
# Data columns (total 40 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         38193 non-null  object
#  1   continent                        37959 non-null  object
#  2   location                         38427 non-null  object
#  3   date                             38427 non-null  object
#  4   total_cases                      37851 non-null  float64
#  5   new_cases                        37681 non-null  float64
#  6   new_cases_smoothed               36900 non-null  float64
#  7   total_deaths                     37851 non-null  float64
#  8   new_deaths                       37681 non-null  float64
#  9   new_deaths_smoothed              36900 non-null  float64
#  10  total_cases_per_million          37617 non-null  float64
# ...

# %%
df.loc

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'tests_units', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# iso_code                                     ABW
# continent                          North America
# location                                   Aruba
# date                                  2020-03-13
# total_cases                                    2
# new_cases                                      2
# new_cases_smoothed                           NaN
# total_deaths                                   0
# new_deaths                                     0
# new_deaths_smoothed                          NaN
# total_cases_per_million                   18.733
# new_cases_per_million                     18.733
# new_cases_smoothed_per_million               NaN
# total_deaths_per_million                       0
# new_deaths_per_million                         0
# new_deaths_smoothed_per_million              NaN
# new_tests                                    NaN
# total_tests                                  NaN
# total_tests_per_thousand                     NaN
# ...

# %%
new_df = df[['continent','location','date','total_cases']]

# %%
new_df.reset_index(inplace=True)

# %%
#new_df.loc[[0,1,2],'total_cases']
#new_df.loc[0:12] - slicing
new_df
# Out:
#        index      continent       location        date  total_cases
# 0          0  North America          Aruba  2020-03-13          2.0
# 1          1  North America          Aruba  2020-03-19          NaN
# 2          2  North America          Aruba  2020-03-20          4.0
# 3          3  North America          Aruba  2020-03-21          NaN
# 4          4  North America          Aruba  2020-03-22          NaN
# ...      ...            ...            ...         ...          ...
# 38422  38422            NaN  International  2020-08-16        696.0
# 38423  38423            NaN  International  2020-08-17        696.0
# 38424  38424            NaN  International  2020-08-18        696.0
# 38425  38425            NaN  International  2020-08-19        696.0
# 38426  38426            NaN  International  2020-08-20        696.0
#
# [38427 rows x 5 columns]

# %%
new_df.head()
# Out:
#    index      continent location        date  total_cases
# 0      0  North America    Aruba  2020-03-13          2.0
# 1      1  North America    Aruba  2020-03-19          NaN
# 2      2  North America    Aruba  2020-03-20          4.0
# 3      3  North America    Aruba  2020-03-21          NaN
# 4      4  North America    Aruba  2020-03-22          NaN

# %%
#Filters 
filter_america = (new_df['total_cases'] > 500)

# %%
new_df[filter_america]
# Out:
#        index      continent       location        date  total_cases
# 144      144  North America          Aruba  2020-08-09        509.0
# 145      145  North America          Aruba  2020-08-10        563.0
# 146      146  North America          Aruba  2020-08-11        630.0
# 147      147  North America          Aruba  2020-08-12        717.0
# 148      148  North America          Aruba  2020-08-13        798.0
# ...      ...            ...            ...         ...          ...
# 38422  38422            NaN  International  2020-08-16        696.0
# 38423  38423            NaN  International  2020-08-17        696.0
# 38424  38424            NaN  International  2020-08-18        696.0
# 38425  38425            NaN  International  2020-08-19        696.0
# 38426  38426            NaN  International  2020-08-20        696.0
#
# [19953 rows x 5 columns]

# %%
new_df['total_cases']
# Out:
# 0          2.0
# 1          NaN
# 2          4.0
# 3          NaN
# 4          NaN
#          ...
# 38422    696.0
# 38423    696.0
# 38424    696.0
# 38425    696.0
# 38426    696.0
# Name: total_cases, Length: 38427, dtype: float64

# %%
new_df = new_df.sort_values(by='total_cases', ascending=False)

# %%
new_df[['location','total_cases']].head(50)
# Out:
#       location  total_cases
# 38192    World   22431929.0
# 38191    World   22158534.0
# 38190    World   21904227.0
# 38189    World   21707306.0
# 38188    World   21475253.0
# 38187    World   21215847.0
# 38186    World   20926641.0
# 38185    World   20639753.0
# 38184    World   20350691.0
# 38183    World   20089684.0
# 38182    World   19869239.0
# 38181    World   19639938.0
# 38180    World   19371672.0
# 38179    World   19095787.0
# 38178    World   18809610.0
# 38177    World   18532292.0
# 38176    World   18276795.0
# 38175    World   18071728.0
# 38174    World   17848024.0
# 38173    World   17580704.0
# 38172    World   17301803.0
# 38171    World   17011356.0
# 38170    World   16713258.0
# 38169    World   16469638.0
# 38168    World   16257403.0
# 38167    World   16025585.0
# 38166    World   15766099.0
# 38165    World   15482211.0
# 38164    World   15205880.0
# 38163    World   14924206.0
# 38162    World   14684529.0
# 38161    World   14483129.0
# ...

# %%
new_df['total_cases'].nlargest(10)
# Out:
# 38192    22431929.0
# 38191    22158534.0
# 38190    21904227.0
# 38189    21707306.0
# 38188    21475253.0
# 38187    21215847.0
# 38186    20926641.0
# 38185    20639753.0
# 38184    20350691.0
# 38183    20089684.0
# Name: total_cases, dtype: float64

# %%
new_df
# Out:
#        index continent      location        date  total_cases
# 38192  38192       NaN         World  2020-08-20   22431929.0
# 38191  38191       NaN         World  2020-08-19   22158534.0
# 38190  38190       NaN         World  2020-08-18   21904227.0
# 38189  38189       NaN         World  2020-08-17   21707306.0
# 38188  38188       NaN         World  2020-08-16   21475253.0
# ...      ...       ...           ...         ...          ...
# 37480  37480    Africa  South Africa  2020-03-03          NaN
# 37481  37481    Africa  South Africa  2020-03-04          NaN
# 37482  37482    Africa  South Africa  2020-03-05          NaN
# 37484  37484    Africa  South Africa  2020-03-07          NaN
# 37488  37488    Africa  South Africa  2020-03-11          NaN
#
# [38427 rows x 5 columns]

# %%
df = pd.read_csv('./owid-covid-data.csv')

# %%
#group by continent
continent_grp = df.groupby(['continent'])

# %%
continent_grp

# %%
continent_grp.get_group('Africa')
# Out:
#       iso_code continent  location        date  total_cases  new_cases  \
# 390        AGO    Africa    Angola  2020-03-22          2.0        2.0
# 391        AGO    Africa    Angola  2020-03-23          2.0        0.0
# 392        AGO    Africa    Angola  2020-03-24          2.0        0.0
# 393        AGO    Africa    Angola  2020-03-25          2.0        0.0
# 394        AGO    Africa    Angola  2020-03-26          2.0        0.0
# ...        ...       ...       ...         ...          ...        ...
# 37954      ZWE    Africa  Zimbabwe  2020-08-16       5176.0      104.0
# 37955      ZWE    Africa  Zimbabwe  2020-08-17       5261.0       85.0
# 37956      ZWE    Africa  Zimbabwe  2020-08-18       5308.0       47.0
# 37957      ZWE    Africa  Zimbabwe  2020-08-19       5378.0       70.0
# 37958      ZWE    Africa  Zimbabwe  2020-08-20       5643.0      265.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
#from continent filter where location == Kenya.
#df.loc[filt]['total_cases'].value_counts().head(50)

# %%
df
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# 2          ABW  North America          Aruba  2020-03-20          4.0
# 3          ABW  North America          Aruba  2020-03-21          NaN
# 4          ABW  North America          Aruba  2020-03-22          NaN
# ...        ...            ...            ...         ...          ...
# 38422      NaN            NaN  International  2020-08-16        696.0
# 38423      NaN            NaN  International  2020-08-17        696.0
# 38424      NaN            NaN  International  2020-08-18        696.0
# 38425      NaN            NaN  International  2020-08-19        696.0
# 38426      NaN            NaN  International  2020-08-20        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df['total_cases'].head(20)
df['total_cases'].median()
# Out:
# 675.0

# %%
#df.median()
#describe -overview of data
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed   total_deaths  \
# count  3.785100e+04   37681.000000        36900.000000   37851.000000
# mean   6.738233e+04    1190.622807         1175.375513    3150.561042
# std    6.959355e+05   10996.964845        10779.190460   29666.491734
# min    0.000000e+00   -2461.000000         -338.857000       0.000000
# 25%    2.900000e+01       0.000000            0.429000       0.000000
# 50%    6.750000e+02       7.000000           11.000000      11.000000
# 75%    7.168000e+03     127.000000          130.749750     143.000000
# max    2.243193e+07  298098.000000       263453.571000  787773.000000
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  37681.000000         36900.000000             37617.000000
# mean      41.812744            41.769144              1363.044146
# std      359.557580           348.908971              3120.072049
# min    -1918.000000          -232.143000                 0.000000
# ...

# %%
df['location'].value_counts()
# Out:
# Netherlands       234
# Sri Lanka         234
# Austria           234
# Armenia           234
# World             234
#                  ...
# Western Sahara    117
# Tajikistan        112
# Comoros           111
# Lesotho            98
# Hong Kong          18
# Name: location, Length: 212, dtype: int64

# %%
location_grp = df.groupby(['location'])

# %%
location_grp.get_group('United States')
# Out:
#       iso_code      continent       location        date  total_cases  \
# 35762      USA  North America  United States  2019-12-31          0.0
# 35763      USA  North America  United States  2020-01-01          0.0
# 35764      USA  North America  United States  2020-01-02          0.0
# 35765      USA  North America  United States  2020-01-03          0.0
# 35766      USA  North America  United States  2020-01-04          0.0
# ...        ...            ...            ...         ...          ...
# 35991      USA  North America  United States  2020-08-16    5361165.0
# 35992      USA  North America  United States  2020-08-17    5403269.0
# 35993      USA  North America  United States  2020-08-18    5438325.0
# 35994      USA  North America  United States  2020-08-19    5482416.0
# 35995      USA  North America  United States  2020-08-20    5529842.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df.dropna()
# Out:
#       iso_code continent    location        date  total_cases  new_cases  \
# 3384       BGD      Asia  Bangladesh  2020-03-17          5.0        2.0
# 3385       BGD      Asia  Bangladesh  2020-03-18          8.0        3.0
# 3386       BGD      Asia  Bangladesh  2020-03-19         10.0        2.0
# 3387       BGD      Asia  Bangladesh  2020-03-20         10.0        0.0
# 3388       BGD      Asia  Bangladesh  2020-03-21         17.0        7.0
# ...        ...       ...         ...         ...          ...        ...
# 37944      ZWE    Africa    Zimbabwe  2020-08-06       4339.0      118.0
# 37945      ZWE    Africa    Zimbabwe  2020-08-07       4395.0       56.0
# 37946      ZWE    Africa    Zimbabwe  2020-08-08       4451.0       56.0
# 37947      ZWE    Africa    Zimbabwe  2020-08-09       4575.0      124.0
# 37948      ZWE    Africa    Zimbabwe  2020-08-10       4649.0       74.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
df2 = df.dropna()

# %%
df2.shape
# Out:
# (2499, 40)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2499 entries, 3384 to 37948
# Data columns (total 40 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         2499 non-null   object
#  1   continent                        2499 non-null   object
#  2   location                         2499 non-null   object
#  3   date                             2499 non-null   object
#  4   total_cases                      2499 non-null   float64
#  5   new_cases                        2499 non-null   float64
#  6   new_cases_smoothed               2499 non-null   float64
#  7   total_deaths                     2499 non-null   float64
#  8   new_deaths                       2499 non-null   float64
#  9   new_deaths_smoothed              2499 non-null   float64
#  10  total_cases_per_million          2499 non-null   float64
# ...

# %%
#replace NaN values to 0
df['total_cases'].fillna(0)
# Out:
# 0          2.0
# 1          0.0
# 2          4.0
# 3          0.0
# 4          0.0
#          ...
# 38422    696.0
# 38423    696.0
# 38424    696.0
# 38425    696.0
# 38426    696.0
# Name: total_cases, Length: 38427, dtype: float64

# %%
df3 = df.loc[0, 'date']

# %%
#convert dates to datetime
#d_parser = lambda x: datetime.strptime(x, '%Y-%m-%d')
df = pd.read_csv('./owid-covid-data.csv', parse_dates=['date'],date_par)

# %%
df
# Out:
#       iso_code      continent       location       date  total_cases  \
# 0          ABW  North America          Aruba 2020-03-13          2.0
# 1          ABW  North America          Aruba 2020-03-19          NaN
# 2          ABW  North America          Aruba 2020-03-20          4.0
# 3          ABW  North America          Aruba 2020-03-21          NaN
# 4          ABW  North America          Aruba 2020-03-22          NaN
# ...        ...            ...            ...        ...          ...
# 38422      NaN            NaN  International 2020-08-16        696.0
# 38423      NaN            NaN  International 2020-08-17        696.0
# 38424      NaN            NaN  International 2020-08-18        696.0
# 38425      NaN            NaN  International 2020-08-19        696.0
# 38426      NaN            NaN  International 2020-08-20        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 0            2.0                 NaN           0.0         0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38427 entries, 0 to 38426
# Data columns (total 40 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   iso_code                         38193 non-null  object
#  1   continent                        37959 non-null  object
#  2   location                         38427 non-null  object
#  3   date                             38427 non-null  datetime64[ns]
#  4   total_cases                      37851 non-null  float64
#  5   new_cases                        37681 non-null  float64
#  6   new_cases_smoothed               36900 non-null  float64
#  7   total_deaths                     37851 non-null  float64
#  8   new_deaths                       37681 non-null  float64
#  9   new_deaths_smoothed              36900 non-null  float64
#  10  total_cases_per_million          37617 non-null  float64
# ...

# %%
new_df = df[["date","iso_code","continent","location","total_cases","new_cases","total_deaths"]]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38427 entries, 0 to 38426
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          38427 non-null  datetime64[ns]
#  1   iso_code      38193 non-null  object
#  2   continent     37959 non-null  object
#  3   location      38427 non-null  object
#  4   total_cases   37851 non-null  float64
#  5   new_cases     37681 non-null  float64
#  6   total_deaths  37851 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 2.1+ MB

# %%
new_df.to_json('./covid_data.json',orient="records")

# %%
date1 = new_df.loc[0,'date']

# %%
date1
# Out:
# Timestamp('2020-03-13 00:00:00')

# %%
date1.date()
# Out:
# datetime.date(2020, 3, 13)

# %%
date1.day
# Out:
# 13

# %%
date1.year
# Out:
# 2020

# %%
date1.month
# Out:
# 3

# %%
df3 = pd.read_json("./covid_data.json")

# %%
df3
# Out:
#             date iso_code      continent       location  total_cases  \
# 0     2020-03-13      ABW  North America          Aruba          2.0
# 1     2020-03-19      ABW  North America          Aruba          NaN
# 2     2020-03-20      ABW  North America          Aruba          4.0
# 3     2020-03-21      ABW  North America          Aruba          NaN
# 4     2020-03-22      ABW  North America          Aruba          NaN
# ...          ...      ...            ...            ...          ...
# 38422 2020-08-16     None           None  International        696.0
# 38423 2020-08-17     None           None  International        696.0
# 38424 2020-08-18     None           None  International        696.0
# 38425 2020-08-19     None           None  International        696.0
# 38426 2020-08-20     None           None  International        696.0
#
#        new_cases  total_deaths
# 0            2.0           0.0
# 1            NaN           NaN
# 2            2.0           0.0
# ...
